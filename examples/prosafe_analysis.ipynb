# %% [markdown]
# ## Prosafe Auto Insure Dataset
# The ProSafe Auto Insure dataset is a large set of synthetic data that is generated on the insurance industry to help insurers understand what goes into the pricing of auto insurance premiums. Although the dataset is likely synthetic, the [Kaggle website hosting the data source](https://www.kaggle.com/datasets/zeesolver/prosafe-auto-insure) claims that this synthetic dataset is recognized industry-wide and is cited in 131 scholarly articles.

# %%
import pandas as pd
from pandasql import sqldf

# %% [markdown]
# Similar to the Allstate example, the datasets can be imported with Pandas' `read_csv()` function, leveraging the `base_dir` variable like so:

# %%
base_dir = "../data_sources/prosafe_dataset"
policy_from_2011_to_2014 = pd.read_csv(f"{base_dir}/policy_from_2011_to_2014.csv")
policy_from_2014_to_2018 = pd.read_csv(f"{base_dir}/policy_from_2014_to_2018.csv")

# %% [markdown]
# We can similarly execute SQL statements against the dataframes using the `sqldf` function:

# %%
sqldf("SELECT * FROM policy_from_2011_to_2014 LIMIT 10;")
# Out:
#    SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE   PREMIUM  \
# 0    0  08-AUG-13  07-AUG-14           08       1202      519755.22  7209.140
# 1    0  08-AUG-12  07-AUG-13           08       1202      519755.22  7203.890
# 2    0  08-AUG-11  07-AUG-12           08       1202      519755.22  7045.804
# 3    0  08-JUL-11  07-AUG-11           08       1202      519755.22   287.250
# 4    0  08-AUG-13  07-AUG-14           08       1202      285451.24  4286.900
# 5    0  08-AUG-12  07-AUG-13           08       1202      285451.24  4286.650
# 6    0  08-AUG-11  07-AUG-12           08       1202      285451.24  4123.564
# 7    0  08-JUL-11  07-AUG-11           08       1202      285451.24   155.010
# 8    0  08-JUL-12  07-JUL-13           11       1201      200000.00  3452.650
# 9    0  08-AUG-11  07-JUL-12           11       1201      200000.00  3077.540
#
#     OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY     TYPE_VEHICLE  \
# 0  5000029885     2007.0        4.0                6.0          Pick-up
# 1  5000029885     2007.0        4.0                6.0          Pick-up
# 2  5000029885     2007.0        4.0                6.0          Pick-up
# 3  5000029885     2007.0        4.0                6.0          Pick-up
# 4  5000029901     2010.0        4.0                7.0          Pick-up
# 5  5000029901     2010.0        4.0                7.0          Pick-up
# 6  5000029901     2010.0        4.0                7.0          Pick-up
# 7  5000029901     2010.0        4.0                7.0          Pick-up
# 8  5000030346     1982.0       10.0                NaN  Station Wagones
# 9  5000030346     1982.0       10.0                NaN  Station Wagones
#
#    CCM_TON    MAKE      USAGE  CLAIM_PAID
# 0   3153.0  NISSAN  Own Goods         NaN
# 1   3153.0  NISSAN  Own Goods         NaN
# 2   3153.0  NISSAN  Own Goods         NaN
# 3   3153.0  NISSAN  Own Goods         NaN
# 4   2494.0  TOYOTA  Own Goods    19894.43
# 5   2494.0  TOYOTA  Own Goods    26916.44
# 6   2494.0  TOYOTA  Own Goods         NaN
# 7   2494.0  TOYOTA  Own Goods         NaN
# 8   4164.0  TOYOTA    Private         NaN
# 9   4164.0  TOYOTA    Private         NaN

# %%
sqldf("SELECT * FROM policy_from_2014_to_2018 LIMIT 10;")
# Out:
#    SEX INSR_BEGIN   INSR_END EFFECTIVE_YR  INSR_TYPE  INSURED_VALUE   PREMIUM  \
# 0    0  08-AUG-17  07-AUG-18           08       1202      519755.22   5097.83
# 1    0  08-AUG-16  07-AUG-17           08       1202      519755.22   6556.52
# 2    0  08-AUG-15  07-AUG-16           08       1202      519755.22   6556.52
# 3    0  08-AUG-14  07-AUG-15           08       1202      519755.22   5102.83
# 4    0  08-AUG-17  07-AUG-18           08       1202     1400000.00  13304.87
# 5    0  08-AUG-16  07-AUG-17           08       1202     1400000.00  16438.15
# 6    0  08-AUG-15  07-AUG-16           08       1202     1400000.00  16438.15
# 7    0  08-AUG-14  07-AUG-15           08       1202      285451.24   3931.23
# 8    1  24-NOV-17  23-NOV-18           12       1202     3400000.00  26804.72
# 9    1  24-NOV-16  23-NOV-17           12       1202     3400000.00  26804.72
#
#     OBJECT_ID  PROD_YEAR  SEATS_NUM  CARRYING_CAPACITY TYPE_VEHICLE  CCM_TON  \
# 0  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 1  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 2  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 3  5000029885     2007.0        4.0                6.0      Pick-up   3153.0
# 4  5000029901     2010.0        4.0                7.0      Pick-up   2494.0
# 5  5000029901     2010.0        4.0                7.0      Pick-up   2494.0
# 6  5000029901     2010.0        4.0                7.0      Pick-up   2494.0
# 7  5000029901     2010.0        4.0                7.0      Pick-up   2494.0
# 8  5000030358     2012.0        0.0              220.0        Truck  12880.0
# 9  5000030358     2012.0        0.0              220.0        Truck  12880.0
#
#      MAKE            USAGE  CLAIM_PAID
# 0  NISSAN        Own Goods         NaN
# 1  NISSAN        Own Goods         NaN
# 2  NISSAN        Own Goods         NaN
# 3  NISSAN        Own Goods         NaN
# 4  TOYOTA        Own Goods         NaN
# 5  TOYOTA        Own Goods         NaN
# 6  TOYOTA        Own Goods   365250.00
# 7  TOYOTA        Own Goods    12152.73
# 8   IVECO  General Cartage         NaN
# 9   IVECO  General Cartage         NaN
